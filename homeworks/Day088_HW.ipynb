# %%
import os
import keras

# 本範例不需使用 GPU, 將 GPU 設定為 "無"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 30
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix

class tp_tn(Callback):
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        # tn, fp, fn, tp
        logs["val_tn"], logs["val_fp"], logs["val_fn"], logs["val_tp"] = confusion_matrix(y_true = y_true, y_pred = y_pred, labels=[0,1]).ravel()
        
log_tp_tn = tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[log_tp_tn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# 在訓練後，將 f1sc 紀錄調出
valid_tp, valid_tn  = model.history.history['val_tp'], model.history.history['val_tn']
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 9s 177us/step - loss: 2.2094 - accuracy: 0.2755 - val_loss: 2.1173 - val_accuracy: 0.2203
# Epoch 2/30
# 50000/50000 [==============================] - 8s 170us/step - loss: 1.7327 - accuracy: 0.3968 - val_loss: 1.9510 - val_accuracy: 0.3259
# Epoch 3/30
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.6114 - accuracy: 0.4361 - val_loss: 1.7988 - val_accuracy: 0.3857
# Epoch 4/30
# 50000/50000 [==============================] - 9s 170us/step - loss: 1.5386 - accuracy: 0.4630 - val_loss: 1.6996 - val_accuracy: 0.4089
# Epoch 5/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.4852 - accuracy: 0.4819 - val_loss: 1.6225 - val_accuracy: 0.4348
# Epoch 6/30
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.4396 - accuracy: 0.4982 - val_loss: 1.5814 - val_accuracy: 0.4438
# Epoch 7/30
# 50000/50000 [==============================] - 9s 170us/step - loss: 1.4020 - accuracy: 0.5112 - val_loss: 1.5428 - val_accuracy: 0.4536
# Epoch 8/30
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.3662 - accuracy: 0.5253 - val_loss: 1.5225 - val_accuracy: 0.4658
# Epoch 9/30
# 50000/50000 [==============================] - 9s 170us/step - loss: 1.3369 - accuracy: 0.5332 - val_loss: 1.5100 - val_accuracy: 0.4721
# Epoch 10/30
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.3071 - accuracy: 0.5457 - val_loss: 1.4942 - val_accuracy: 0.4783
# Epoch 11/30
# 50000/50000 [==============================] - 9s 173us/step - loss: 1.2804 - accuracy: 0.5560 - val_loss: 1.4992 - val_accuracy: 0.4765
# Epoch 12/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.2559 - accuracy: 0.5650 - val_loss: 1.4842 - val_accuracy: 0.4777
# Epoch 13/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.2291 - accuracy: 0.5753 - val_loss: 1.4718 - val_accuracy: 0.4827
# Epoch 14/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.2033 - accuracy: 0.5859 - val_loss: 1.4774 - val_accuracy: 0.4776
# Epoch 15/30
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.1797 - accuracy: 0.5944 - val_loss: 1.4783 - val_accuracy: 0.4856
# Epoch 16/30
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.1559 - accuracy: 0.6036 - val_loss: 1.4695 - val_accuracy: 0.4850
# Epoch 17/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.1337 - accuracy: 0.6107 - val_loss: 1.4662 - val_accuracy: 0.4851
# Epoch 18/30
# 50000/50000 [==============================] - 9s 173us/step - loss: 1.1108 - accuracy: 0.6188 - val_loss: 1.4653 - val_accuracy: 0.4897
# Epoch 19/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.0867 - accuracy: 0.6285 - val_loss: 1.4659 - val_accuracy: 0.4892
# Epoch 20/30
# 50000/50000 [==============================] - 9s 174us/step - loss: 1.0670 - accuracy: 0.6360 - val_loss: 1.4712 - val_accuracy: 0.4880
# Epoch 21/30
# 50000/50000 [==============================] - 10s 201us/step - loss: 1.0461 - accuracy: 0.6436 - val_loss: 1.4627 - val_accuracy: 0.4951
# Epoch 22/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.0258 - accuracy: 0.6525 - val_loss: 1.4665 - val_accuracy: 0.4921
# Epoch 23/30
# 50000/50000 [==============================] - 9s 174us/step - loss: 1.0023 - accuracy: 0.6615 - val_loss: 1.4669 - val_accuracy: 0.4934
# Epoch 24/30
# 50000/50000 [==============================] - 9s 173us/step - loss: 0.9820 - accuracy: 0.6689 - val_loss: 1.4682 - val_accuracy: 0.4942
# Epoch 25/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 0.9615 - accuracy: 0.6773 - val_loss: 1.4651 - val_accuracy: 0.4928
# Epoch 26/30
# 50000/50000 [==============================] - 9s 173us/step - loss: 0.9409 - accuracy: 0.6842 - val_loss: 1.4747 - val_accuracy: 0.4920
# Epoch 27/30
# 50000/50000 [==============================] - 9s 173us/step - loss: 0.9209 - accuracy: 0.6931 - val_loss: 1.4775 - val_accuracy: 0.4925
# Epoch 28/30
# 50000/50000 [==============================] - 9s 174us/step - loss: 0.9021 - accuracy: 0.7007 - val_loss: 1.4925 - val_accuracy: 0.4874
# Epoch 29/30
# 50000/50000 [==============================] - 9s 173us/step - loss: 0.8812 - accuracy: 0.7072 - val_loss: 1.4899 - val_accuracy: 0.4940
# Epoch 30/30
# 50000/50000 [==============================] - 9s 172us/step - loss: 0.8623 - accuracy: 0.7143 - val_loss: 1.4880 - val_accuracy: 0.4954

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid_tp")
plt.legend()
plt.title("valid_tp")
plt.show()

plt.plot(range(len(valid_tn)), valid_tn, label="valid_tn")
plt.legend()
plt.title("valid_tn")
plt.show()
